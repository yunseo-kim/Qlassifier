# %%
from google.colab import drive
drive.mount('/content/drive')
# and change current directory to Hojun \Lee
# Out:
# Mounted at /content/drive

# %%
# !pip3 install qiskit

# %%
# !git pull
# Out:
# remote: Enumerating objects: 22, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 14 (delta 7), reused 14 (delta 7), pack-reused 0
# Unpacking objects: 100% (14/14), done.
# From https://github.com/Yunseo47/Qlassifier
#    595769f..d4dad0a  main       -> origin/main
# Updating 595769f..d4dad0a
# Fast-forward
#  Hojun Lee/QNN.ipynb                             | 297 ++++++-----
#  Hojun Lee/QNN_PQC.ipynb                         | 630 ++++++++++++++++++++++++
#  Hojun Lee/quanvolution/q_test_images_f1_c9.npy  | Bin 0 -> 1460288 bytes
#  Hojun Lee/quanvolution/q_train_images_f1_c9.npy | Bin 0 -> 2433728 bytes
#  4 files changed, 800 insertions(+), 127 deletions(-)
#  create mode 100644 Hojun Lee/QNN_PQC.ipynb
#  create mode 100644 Hojun Lee/quanvolution/q_test_images_f1_c9.npy
#  create mode 100644 Hojun Lee/quanvolution/q_train_images_f1_c9.npy

# %%
import PQC
from qiskit import Aer
import numpy as np
from torchvision import datasets, transforms
import torch
from torch.autograd import Variable
from QuanvolutionLayerFile import *

# %%
Aer.backends()
# Out:
# [AerSimulator('aer_simulator'),
#  AerSimulator('aer_simulator_statevector'),
#  AerSimulator('aer_simulator_density_matrix'),
#  AerSimulator('aer_simulator_stabilizer'),
#  AerSimulator('aer_simulator_matrix_product_state'),
#  AerSimulator('aer_simulator_extended_stabilizer'),
#  AerSimulator('aer_simulator_unitary'),
#  AerSimulator('aer_simulator_superop'),
#  QasmSimulator('qasm_simulator'),
#  StatevectorSimulator('statevector_simulator'),
#  UnitarySimulator('unitary_simulator'),
#  PulseSimulator('pulse_simulator')]

# %%
# Run the quantum circuit on a statevector simulator backend
backend = Aer.get_backend('qasm_simulator')
qc = PQC.QuantumCircuit(backend=backend)

# %%
print(torch.rand(1,27))
print(qc.run(data=None,params_tensor=torch.rand(27)))
# Out:
# tensor([[0.9933, 0.4683, 0.1072, 0.6192, 0.6258, 0.0685, 0.4892, 0.5894, 0.5531,
#          0.4138, 0.4803, 0.1877, 0.2812, 0.7244, 0.0370, 0.9811, 0.6503, 0.3915,
#          0.8042, 0.1340, 0.7943, 0.7606, 0.7934, 0.1064, 0.0690, 0.1816, 0.7476]])
# [0.1328125]

# %%
BATCH_SIZE = 16

# %%
train_dataset = datasets.MNIST(root = "./data",
                               train = True,
                               download = True,
                               transform = transforms.ToTensor())

test_dataset = datasets.MNIST(root = "./data",
                              train = False,
                              transform = transforms.ToTensor())

train_loader = torch.utils.data.DataLoader(dataset = train_dataset,
                                           batch_size = BATCH_SIZE,
                                           shuffle = True)

test_loader = torch.utils.data.DataLoader(dataset = test_dataset,
                                          batch_size = BATCH_SIZE,
                                          shuffle = False)

# %%
print(train_dataset)
# Out:
# Dataset MNIST
#     Number of datapoints: 60000
#     Root location: ./data
#     Split: Train
#     StandardTransform
# Transform: ToTensor()

# %%
for x_train, y_train in train_loader:
    print(x_train.size(),y_train.size())
    break
# Out:
# torch.Size([16, 1, 28, 28]) torch.Size([16])

# %%
ql = QuanvolutionLayer(out_channels=1,kernel_size=3,backend=backend)
print(ql.weight)
for x_train, y_train in train_loader:
    print(x_train.size(),y_train.size())
    processed = ql.forward(inputs=x_train)
    print(processed)
    break
# Out:
# tensor([[1.4044, 0.1716, 4.2868, 1.3259, 6.0762, 1.8763, 0.3775, 4.3672, 3.2574,
#          4.0364, 6.1930, 1.4406, 2.1579, 2.7534, 2.9879, 2.3235, 0.9611, 4.1024,
#          5.5798, 1.4593, 5.6004, 5.9136, 2.2014, 3.1194, 0.1721, 5.3452, 3.4247]])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# 0
# 0
# 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-bc8833364024> in <module>()
#       3 for x_train, y_train in train_loader:
#       4     print(x_train.size(),y_train.size())
# ----> 5     processed = ql.forward(inputs=x_train)
#       6     print(processed)
#       7     break
#
# /content/drive/My Drive/Quantum Computer/qcnn/Qlassifier/Hojun Lee/QuanvolutionLayerFile.py in forward(self, inputs)
#      54     def forward(self,inputs):
#      55         return QuanvolutionFunction.apply(inputs,self.out_channels,self.kernel_size,
# ---> 56         self.quantum_circuit,np.pi/2,self.weight)
#      57     def update_weight(self,grad_weight,lr=0.001):
#      58         self.weight -= grad_weight * lr
#
# /content/drive/My Drive/Quantum Computer/qcnn/Qlassifier/Hojun Lee/QuanvolutionLayerFile.py in forward(ctx, inputs, out_channels, kernel_size, quantum_circuit, shift, weight)
#      29                         # print(x,y)
#      30                         data = input[0, x:x+kernel_size, y:y+kernel_size]
# ---> 31                         ys.append(quantum_circuit.run(data.flatten(),weight[i]))
#      32                     xys.append(ys)
#      33                 feature.append(xys)
#
# /content/drive/My Drive/Quantum Computer/qcnn/Qlassifier/Hojun Lee/PQC.py in run(self, data, params_tensor)
#      60         circ.measure(0,0)
#      61         # circ.measure(range(self.output_channels),range(self.output_channels))
# ---> 62         job = qiskit.execute(circ, backend=self.backend,shots=self.shots)
#      63         result = job.result().get_counts()
#      64         # print(result)
#
# /usr/local/lib/python3.7/dist-packages/qiskit/execute_function.py in execute(experiments, backend, basis_gates, coupling_map, backend_properties, initial_layout, seed_transpiler, optimization_level, pass_manager, qobj_id, qobj_header, shots, memory, max_credits, seed_simulator, default_qubit_los, default_meas_los, schedule_los, meas_level, meas_return, memory_slots, memory_slot_size, rep_time, rep_delay, parameter_binds, schedule_circuit, inst_map, meas_map, scheduling_method, init_qubits, **run_config)
#     257                                 seed_transpiler=seed_transpiler,
#     258                                 optimization_level=optimization_level,
# --> 259                                 backend=backend)
#     260
#     261     if schedule_circuit:
#
# /usr/local/lib/python3.7/dist-packages/qiskit/compiler/transpiler.py in transpile(circuits, backend, basis_gates, coupling_map, backend_properties, initial_layout, layout_method, routing_method, translation_method, scheduling_method, instruction_durations, dt, approximation_degree, seed_transpiler, optimization_level, pass_manager, callback, output_name)
#     243
#     244     # Transpile circuits in parallel
# --> 245     circuits = parallel_map(_transpile_circuit, list(zip(circuits, transpile_args)))
#     246
#     247     end_time = time()
#
# /usr/local/lib/python3.7/dist-packages/qiskit/tools/parallel.py in parallel_map(task, values, task_args, task_kwargs, num_processes)
#     126         return []
#     127     if len(values) == 1:
# --> 128         return [task(values[0], *task_args, **task_kwargs)]
#     129
#     130     Publisher().publish("terra.parallel.start", len(values))
#
# /usr/local/lib/python3.7/dist-packages/qiskit/compiler/transpiler.py in _transpile_circuit(circuit_config_tuple)
#     327
#     328     result = pass_manager.run(circuit, callback=transpile_config['callback'],
# --> 329                               output_name=transpile_config['output_name'])
#     330
#     331     if transpile_config['faulty_qubits_map']:
#
# /usr/local/lib/python3.7/dist-packages/qiskit/transpiler/passmanager.py in run(self, circuits, output_name, callback)
#     214         """
#     215         if isinstance(circuits, QuantumCircuit):
# --> 216             return self._run_single_circuit(circuits, output_name, callback)
#     217         elif len(circuits) == 1:
#     218             return self._run_single_circuit(circuits[0], output_name, callback)
#
# /usr/local/lib/python3.7/dist-packages/qiskit/transpiler/passmanager.py in _run_single_circuit(self, circuit, output_name, callback)
#     275         """
#     276         running_passmanager = self._create_running_passmanager()
# --> 277         result = running_passmanager.run(circuit, output_name=output_name, callback=callback)
#     278         self.property_set = running_passmanager.property_set
#     279         return result
#
# /usr/local/lib/python3.7/dist-packages/qiskit/transpiler/runningpassmanager.py in run(***failed resolving arguments***)
#     120         for passset in self.working_list:
#     121             for pass_ in passset:
# --> 122                 dag = self._do_pass(pass_, dag, passset.options)
#     123
#     124         circuit = dag_to_circuit(dag)
#
# /usr/local/lib/python3.7/dist-packages/qiskit/transpiler/runningpassmanager.py in _do_pass(self, pass_, dag, options)
#     151         # Run the pass itself, if not already run
#     152         if pass_ not in self.valid_passes:
# --> 153             dag = self._run_this_pass(pass_, dag)
#     154
#     155             # update the valid_passes property
#
# /usr/local/lib/python3.7/dist-packages/qiskit/transpiler/runningpassmanager.py in _run_this_pass(self, pass_, dag)
#     163             # Measure time if we have a callback or logging set
#     164             start_time = time()
# --> 165             new_dag = pass_.run(dag)
#     166             end_time = time()
#     167             run_time = end_time - start_time
#
# /usr/local/lib/python3.7/dist-packages/qiskit/transpiler/passes/optimization/optimize_1q_decomposition.py in run(self, dag)
#      99                 operator = gate.op.to_matrix().dot(operator)
#     100             for decomposer in self.basis:
# --> 101                 new_circs.append(decomposer._decompose(operator))
#     102             if new_circs:
#     103                 new_circ = min(new_circs, key=len)
#
# /usr/local/lib/python3.7/dist-packages/qiskit/quantum_info/synthesis/one_qubit_decompose.py in _decompose(self, unitary, simplify, atol)
#     148
#     149     def _decompose(self, unitary, simplify=True, atol=DEFAULT_ATOL):
# --> 150         theta, phi, lam, phase = self._params(unitary)
#     151         circuit = self._circuit(theta, phi, lam, phase,
#     152                                 simplify=simplify,
#
# /usr/local/lib/python3.7/dist-packages/qiskit/quantum_info/synthesis/one_qubit_decompose.py in _params_u1x(mat)
#     262         # Since the phase is wrt to a SU matrix we must rescale
#     263         # phase to correct this
# --> 264         theta, phi, lam, phase = OneQubitEulerDecomposer._params_zyz(mat)
#     265         return theta, phi, lam, phase - 0.5 * (theta + phi + lam)
#     266
#
# /usr/local/lib/python3.7/dist-packages/qiskit/quantum_info/synthesis/one_qubit_decompose.py in _params_zyz(mat)
#     207         # We rescale the input matrix to be special unitary (det(U) = 1)
#     208         # This ensures that the quaternion representation is real
# --> 209         coeff = la.det(mat)**(-0.5)
#     210         phase = -np.angle(coeff)
#     211         su_mat = coeff * mat  # U in SU(2)
#
# /usr/local/lib/python3.7/dist-packages/scipy/linalg/basic.py in det(a, overwrite_a, check_finite)
#    1032
#    1033     """
# -> 1034     a1 = _asarray_validated(a, check_finite=check_finite)
#    1035     if len(a1.shape) != 2 or a1.shape[0] != a1.shape[1]:
#    1036         raise ValueError('expected square matrix')
#
# /usr/local/lib/python3.7/dist-packages/scipy/_lib/_util.py in _asarray_validated(a, check_finite, sparse_ok, objects_ok, mask_ok, as_inexact)
#     246     a = toarray(a)
#     247     if not objects_ok:
# --> 248         if a.dtype is np.dtype('O'):
#     249             raise ValueError('object arrays are not supported')
#     250     if as_inexact:
#
# KeyboardInterrupt:

# %%
print(processed.size())
# Out:
# torch.Size([16, 1, 26, 26])
